# %%
import pandas as pd
from IPython.display import display
from PIL import Image

# %%
df4 = pd.read_csv('time_vs_vlockin_linearity4cm.csv')

# %%
df6p5 = pd.read_csv('time_vs_vlockin_linearity6p5cm.csv')

# %%
df9p1 = pd.read_csv('time_vs_vlockin_linearity9p1cm.csv')

# %%
df11p4 = pd.read_csv('time_vs_vlockin_linearity11p4cm.csv')

# %%
df16p7 = pd.read_csv('time_vs_vlockin_linearity16p7cm.csv')

# %%
df21p8 = pd.read_csv('time_vs_vlockin_linearity21p8cm.csv')

# %%
df31p9 = pd.read_csv('time_vs_vlockin_linearity31p9cm.csv')

# %%
df42p1 = pd.read_csv('time_vs_vlockin_linearity42p1cm.csv')

# %%
display(Image.open('time_vs_vlockin_linearity4cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary4 = df4['Vlockin (microvolts)'].describe()
summary4.T
# Out:
# count    488.000000
# mean     242.286822
# std       16.071840
# min      217.975000
# 25%      231.029000
# 50%      237.645000
# 75%      255.184000
# max      280.561000
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity6p5cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary6p5 = df6p5['Vlockin (microvolts)'].describe()
summary6p5.T
# Out:
# count    484.000000
# mean     263.819884
# std       14.233885
# min      139.774000
# 25%      256.540000
# 50%      262.575500
# 75%      271.188000
# max      431.987000
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity9p1cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary9p1 = df9p1['Vlockin (microvolts)'].describe()
summary9p1.T
# Out:
# count    482.000000
# mean     141.667836
# std       14.414207
# min      125.320000
# 25%      135.572000
# 50%      141.145000
# 75%      145.287000
# max      356.944000
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity11p4cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary11p4 = df11p4['Vlockin (microvolts)'].describe()
summary11p4.T
# Out:
# count    490.000000
# mean     100.017181
# std        5.051691
# min       89.869400
# 25%       96.016100
# 50%       99.849400
# 75%      103.981000
# max      111.014000
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity16p7cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary16p7 = df16p7['Vlockin (microvolts)'].describe()
summary16p7.T
# Out:
# count    501.000000
# mean      57.773341
# std        4.727395
# min       48.131000
# 25%       54.128700
# 50%       57.675200
# 75%       61.419300
# max       67.495300
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity21p8cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary21p8 = df21p8['Vlockin (microvolts)'].describe()
summary21p8.T
# Out:
# count    506.000000
# mean      29.888949
# std        3.599925
# min       20.757400
# 25%       26.595925
# 50%       30.089250
# 75%       33.165550
# max       40.311600
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity31p9cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary31p9 = df31p9['Vlockin (microvolts)'].describe()
summary31p9.T
# Out:
# count    492.000000
# mean      13.686854
# std        3.826340
# min        2.902020
# 25%       10.009010
# 50%       14.236250
# 75%       17.297550
# max       20.358800
# Name: Vlockin (microvolts), dtype: float64

# %%
display(Image.open('time_vs_vlockin_linearity42p1cm.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
summary42p1 = df42p1['Vlockin (microvolts)'].describe()
summary42p1.T
# Out:
# count    493.000000
# mean       9.065034
# std        2.987176
# min        2.687810
# 25%        6.454090
# 50%        9.523760
# 75%       11.684400
# max       14.824900
# Name: Vlockin (microvolts), dtype: float64

# %%
combined_summary = pd.concat([summary4.T, summary6p5.T, summary9p1.T, summary11p4.T, summary16p7.T, summary21p8.T, summary31p9.T, summary42p1.T], axis=1)
combined_summary
# Out:
#        Vlockin (microvolts)  Vlockin (microvolts)  Vlockin (microvolts)  \
# count            488.000000            484.000000            482.000000
# mean             242.286822            263.819884            141.667836
# std               16.071840             14.233885             14.414207
# min              217.975000            139.774000            125.320000
# 25%              231.029000            256.540000            135.572000
# 50%              237.645000            262.575500            141.145000
# 75%              255.184000            271.188000            145.287000
# max              280.561000            431.987000            356.944000
#
#        Vlockin (microvolts)  Vlockin (microvolts)  Vlockin (microvolts)  \
# count            490.000000            501.000000            506.000000
# mean             100.017181             57.773341             29.888949
# std                5.051691              4.727395              3.599925
# ...

# %%
#combined_summary.columns['3.994cm', '6.534cm', '9.074cm', '11.614cm', '16.694cm', '21.774cm', '31.934cm', '42.094cm']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 combined_summary.columns['3.994cm', '6.534cm', '9.074cm', '11.614cm', '16.694cm', '21.774cm', '31.934cm', '42.094cm']
#
# File ~\.conda\envs\anl\Lib\site-packages\pandas\core\indexes\base.py:5416, in Index.__getitem__(self, key)
#    5407         if len(key) == 0 and len(key) != len(self):
#    5408             warnings.warn(
#    5409                 "Using a boolean indexer with length 0 on an Index with "
#    5410                 "length greater than 0 is deprecated and will raise in a "
#    (...)
#    5413                 stacklevel=find_stack_level(),
#    5414             )
# -> 5416 result = getitem(key)
#    5417 # Because we ruled out integer above, we always get an arraylike here
#    5418 if result.ndim > 1:
#
# ...

# %%
combined_summary.to_csv('linearit_combined_summary.csv', index = False)
