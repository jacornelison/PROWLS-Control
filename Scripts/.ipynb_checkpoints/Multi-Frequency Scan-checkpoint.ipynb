# %%
#Imports
import base64
import sys
import os
import time
import pandas as pd
import matplotlib.pyplot as plt
import pyvisa
import logging
from time import sleep
from toptica.lasersdk.client import Client, SerialConnection, UserLevel, Subscription, Timestamp, SubscriptionValue

# %%
#Configuration Variables
log_file = "../Data/Internal_Reflection_Test/Logs/f_vs_vlockin_intref_24p314.log" #name of log file
plot_file = '../Data/Internal_Reflection_Test/Plots/f_vs_vlockin_intref_24p314.png' #name of plot file
csv_file = '../Data/Internal_Reflection_Test/Tables/f_vs_vlockin_intref_24p314.csv' #name of csv file
warm_up_time = 0 #In seconds, how long PROWLS should wait at desired settings before taking data
power_down = True #True or False, if PROWLS should power down after data acquisition
lockin_address = 'GPIB::8::INSTR' #connection to DLC Smart
dlc_connection_port = 'COM3' #connection to lock-in amplifier
bias_frequency = 1000 #in Hz, the bias frequency of DLC Smart and the lock-in amplifier
sensitivity_setting = 15 #lock-in sensitivity setting, specifics found in SR830 manual  
time_constant = 8 #lock-in time constant setting, specifics found in SR830 manual
low_pass_filter = 0 #lock-in low pass filter slope setting, specifics found in SR830 manual
start_frequency = 70 #in GHz, the smallest frequency to measure
end_frequency = 600 #in GHz, the largest frequency to measure 
frequency_increment = 1 #in GHz, step size between each measurement
frequency_tolerance = 0.1 #in GHz, how much difference between desired and actual frequency is allowed for each measurement

# %%
#Ensure directories exist for files
for file_path in [log_file, plot_file, csv_file]:
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
#Configure logging
logging.basicConfig(filename = log_file, level = logging.INFO, format = '%(asctime)s - %(levelname)s - %(message)s')
def log_and_print(message):
    logging.info(message)
    print(message)

# %%
#Set up connection with lock-in amplifier
rm = pyvisa.ResourceManager()
lockin = rm.open_resource(lockin_address)
idn = lockin.query('*IDN?')
log_and_print(f'Connected to: {idn}')
# Out:
# Connected to: Stanford_Research_Systems,SR830,s/n46458,ver1.07

# %%
#Set up connection with DLC smart and check user level
with Client(SerialConnection(dlc_connection_port)) as client:
    user_level = client.get('ul')
    dlc_smart = client.get('general:system-type')
    log_and_print(f'Connected to: {dlc_smart}')
    log_and_print(f"Current User Level: {user_level}")
# Out:
# Connected to: DLCsmartTHz
# Current User Level: 3

# %%
#Turn on lasers (check emission lights)
#If lasers do not power on, check the frontkey and user level
with Client(SerialConnection(dlc_connection_port)) as client:
    client.set('laser-operation:emission-global-enable', True)
    log_and_print(f'Lasers on: {client.get('laser-operation:emission-global-enable')}')
#Wait 5 seconds for lasers to adjust
time.sleep(5)
# Out:
# Lasers on: True

# %%
#Set DLC Smart bias amplitude (0.8V), offset (-0.30V), and frequency
with Client(SerialConnection(dlc_connection_port)) as client:
    client.set('lockin:mod-out-amplitude', 0.80) 
    client.set('lockin:mod-out-offset', -0.30)
    client.set('lockin:frequency', bias_frequency)
    log_and_print(f"Current DLC Smart Bias Amplitude (V): {client.get('lockin:mod-out-amplitude')}")
    log_and_print(f"Current DLC Smart Bias Offset (V): {client.get('lockin:mod-out-offset')}")
    log_and_print(f"Current DLC Smart Bias Frequency (Hz): {client.get('lockin:frequency')}")
#wait 5 seconds for DLC smart to adjust
time.sleep(5)
# Out:
# Current DLC Smart Bias Amplitude (V): 0.800018310546875
# Current DLC Smart Bias Offset (V): -0.30002441704309607
# Current DLC Smart Bias Frequency (Hz): 1000

# %%
#Set laser frequency to starting frequency
with Client(SerialConnection(dlc_connection_port)) as client:
    client.set('frequency:frequency-set', start_frequency)
    log_and_print(f"Current DLC Smart Frequency (GHz): {client.get('frequency:frequency-act')}")
# Out:
# Current DLC Smart Frequency (GHz): 599.9989929362782

# %%
#Set lock-in sensitivity, time constant, low pass filter, and bias frequency
lockin.write(f'SENS {sensitivity_setting}')
lockin.write(f'OFLT {time_constant}')
lockin.write(f'OFSL {low_pass_filter}')
lockin.write(f'FREQ {bias_frequency}')
log_and_print(f"Current Lock-in Sensitivity setting: {lockin.query('SENS?')}")
log_and_print(f'Current Time Constant: {lockin.query('OFLT?')}')
log_and_print(f'Current Low Pass Filter: {lockin.query('OFSL?')}')
log_and_print(f"Current Lock-in Bias Frequency (Hz): {lockin.query('FREQ?')}")
# Out:
# Current Lock-in Sensitivity setting: 15
#
# Current Time Constant: 8
#
# Current Low Pass Filter: 0
#
# Current Lock-in Bias Frequency (Hz): 1000

# %%
#Wait the warm-up time
log_and_print(f'Waiting the {warm_up_time} second warm-up time')
time.sleep(warm_up_time)
# Out:
# Waiting the 0 second warm-up time

# %%
#Empty dataframe
data = {'Desired Frequency (GHz)': [], 'Measured Frequency (GHz)': [], 'Vlockin (microvolts)': [],}

# %%
#Collect frequency vs. vlockin data
log_and_print(f"Frequency Scan Range (GHz):{start_frequency}-{end_frequency}")
log_and_print(f"Frequency Increment (GHz): {frequency_increment}")
log_and_print(f"Frequency Tolerance (GHz): {frequency_tolerance}")
log_and_print('BEGINNING DATA ACQUISITION')
with Client(SerialConnection(dlc_connection_port)) as client:
    for frequency in range (start_frequency, end_frequency+1, frequency_increment):
        try: 
            #set frequency
            client.set('frequency:frequency-set', frequency)
            #get actual frequency from DLC Smart
            measured_frequency = client.get('frequency:frequency-act')
            #loop until the measured frequency is close to the desired frequency
            while abs(measured_frequency - frequency) > frequency_tolerance:
                #get actual frequency from DLC Smart
                measured_frequency = client.get('frequency:frequency-act')
            #get voltage from lock-in, convert to microvolts
            vlockin = float(lockin.query('OUTP?3')) * 1e6
            #append the frequency and Vlockin to dataframe
            data['Desired Frequency (GHz)'].append(frequency)
            data['Measured Frequency (GHz)'].append(measured_frequency)
            data['Vlockin (microvolts)'].append((vlockin))
            #get voltage from lock-in, convert to microvolts
            log_and_print(f"Appended data for frequency {frequency} GHz") #- Measured Frequency: {measured_frequency} GHz, Vlockin: {vlockin} microvolts")
    #append None if there is an error in measurement        
        except Exception as e:
            log_and_print(f"Error at frequency {frequency} GHz: {e}")
            data['Desired Frequency (GHz)'].append(frequency)
            data['Measured Frequency (GHz)'].append(None)
            data['Vlockin (microvolts)'].append(None)
            log_and_print(f"Appended None for frequency {frequency} GHz due to error")
log_and_print('DATA ACQUISITION COMPLETE')
#convert dict to dataframe
df = pd.DataFrame(data)
# Out:
# Frequency Scan Range (GHz):70-600
# Frequency Increment (GHz): 1
# Frequency Tolerance (GHz): 0.1
# BEGINNING DATA ACQUISITION
# Appended data for frequency 70 GHz
# Appended data for frequency 71 GHz
# Appended data for frequency 72 GHz
# Appended data for frequency 73 GHz
# Appended data for frequency 74 GHz
# Appended data for frequency 75 GHz
# Appended data for frequency 76 GHz
# Appended data for frequency 77 GHz
# Appended data for frequency 78 GHz
# Appended data for frequency 79 GHz
# Appended data for frequency 80 GHz
# Appended data for frequency 81 GHz
# Appended data for frequency 82 GHz
# Appended data for frequency 83 GHz
# Appended data for frequency 84 GHz
# Appended data for frequency 85 GHz
# Appended data for frequency 86 GHz
# Appended data for frequency 87 GHz
# Appended data for frequency 88 GHz
# Appended data for frequency 89 GHz
# Appended data for frequency 90 GHz
# Appended data for frequency 91 GHz
# Appended data for frequency 92 GHz
# Appended data for frequency 93 GHz
# Appended data for frequency 94 GHz
# Appended data for frequency 95 GHz
# Appended data for frequency 96 GHz
# Appended data for frequency 97 GHz
# Appended data for frequency 98 GHz
# Appended data for frequency 99 GHz
# Appended data for frequency 100 GHz
# Appended data for frequency 101 GHz
# Appended data for frequency 102 GHz
# Appended data for frequency 103 GHz
# Appended data for frequency 104 GHz
# Appended data for frequency 105 GHz
# Appended data for frequency 106 GHz
# Appended data for frequency 107 GHz
# Appended data for frequency 108 GHz
# Appended data for frequency 109 GHz
# Appended data for frequency 110 GHz
# Appended data for frequency 111 GHz
# Appended data for frequency 112 GHz
# Appended data for frequency 113 GHz
# Appended data for frequency 114 GHz
# Appended data for frequency 115 GHz
# Appended data for frequency 116 GHz
# Appended data for frequency 117 GHz
# Appended data for frequency 118 GHz
# Appended data for frequency 119 GHz
# Appended data for frequency 120 GHz
# Appended data for frequency 121 GHz
# Appended data for frequency 122 GHz
# Appended data for frequency 123 GHz
# Appended data for frequency 124 GHz
# Appended data for frequency 125 GHz
# Appended data for frequency 126 GHz
# Appended data for frequency 127 GHz
# Appended data for frequency 128 GHz
# Appended data for frequency 129 GHz
# Appended data for frequency 130 GHz
# Appended data for frequency 131 GHz
# Appended data for frequency 132 GHz
# Appended data for frequency 133 GHz
# Appended data for frequency 134 GHz
# Appended data for frequency 135 GHz
# Appended data for frequency 136 GHz
# Appended data for frequency 137 GHz
# Appended data for frequency 138 GHz
# Appended data for frequency 139 GHz
# Appended data for frequency 140 GHz
# Appended data for frequency 141 GHz
# Appended data for frequency 142 GHz
# Appended data for frequency 143 GHz
# Appended data for frequency 144 GHz
# Appended data for frequency 145 GHz
# Appended data for frequency 146 GHz
# Appended data for frequency 147 GHz
# Appended data for frequency 148 GHz
# Appended data for frequency 149 GHz
# Appended data for frequency 150 GHz
# Appended data for frequency 151 GHz
# Appended data for frequency 152 GHz
# Appended data for frequency 153 GHz
# Appended data for frequency 154 GHz
# Appended data for frequency 155 GHz
# Appended data for frequency 156 GHz
# Appended data for frequency 157 GHz
# Appended data for frequency 158 GHz
# Appended data for frequency 159 GHz
# Appended data for frequency 160 GHz
# Appended data for frequency 161 GHz
# Appended data for frequency 162 GHz
# Appended data for frequency 163 GHz
# Appended data for frequency 164 GHz
# Appended data for frequency 165 GHz
# Appended data for frequency 166 GHz
# Appended data for frequency 167 GHz
# Appended data for frequency 168 GHz
# Appended data for frequency 169 GHz
# Appended data for frequency 170 GHz
# Appended data for frequency 171 GHz
# Appended data for frequency 172 GHz
# Appended data for frequency 173 GHz
# Appended data for frequency 174 GHz
# Appended data for frequency 175 GHz
# Appended data for frequency 176 GHz
# Appended data for frequency 177 GHz
# Appended data for frequency 178 GHz
# Appended data for frequency 179 GHz
# Appended data for frequency 180 GHz
# Appended data for frequency 181 GHz
# Appended data for frequency 182 GHz
# Appended data for frequency 183 GHz
# Appended data for frequency 184 GHz
# Appended data for frequency 185 GHz
# Appended data for frequency 186 GHz
# Appended data for frequency 187 GHz
# Appended data for frequency 188 GHz
# Appended data for frequency 189 GHz
# Appended data for frequency 190 GHz
# Appended data for frequency 191 GHz
# Appended data for frequency 192 GHz
# Appended data for frequency 193 GHz
# Appended data for frequency 194 GHz
# Appended data for frequency 195 GHz
# Appended data for frequency 196 GHz
# Appended data for frequency 197 GHz
# Appended data for frequency 198 GHz
# Appended data for frequency 199 GHz
# Appended data for frequency 200 GHz
# Appended data for frequency 201 GHz
# Appended data for frequency 202 GHz
# Appended data for frequency 203 GHz
# Appended data for frequency 204 GHz
# Appended data for frequency 205 GHz
# Appended data for frequency 206 GHz
# Appended data for frequency 207 GHz
# Appended data for frequency 208 GHz
# Appended data for frequency 209 GHz
# Appended data for frequency 210 GHz
# Appended data for frequency 211 GHz
# Appended data for frequency 212 GHz
# Appended data for frequency 213 GHz
# Appended data for frequency 214 GHz
# Appended data for frequency 215 GHz
# Appended data for frequency 216 GHz
# Appended data for frequency 217 GHz
# Appended data for frequency 218 GHz
# Appended data for frequency 219 GHz
# Appended data for frequency 220 GHz
# Appended data for frequency 221 GHz
# Appended data for frequency 222 GHz
# Appended data for frequency 223 GHz
# Appended data for frequency 224 GHz
# Appended data for frequency 225 GHz
# Appended data for frequency 226 GHz
# Appended data for frequency 227 GHz
# Appended data for frequency 228 GHz
# Appended data for frequency 229 GHz
# Appended data for frequency 230 GHz
# Appended data for frequency 231 GHz
# Appended data for frequency 232 GHz
# Appended data for frequency 233 GHz
# Appended data for frequency 234 GHz
# Appended data for frequency 235 GHz
# Appended data for frequency 236 GHz
# Appended data for frequency 237 GHz
# Appended data for frequency 238 GHz
# Appended data for frequency 239 GHz
# Appended data for frequency 240 GHz
# Appended data for frequency 241 GHz
# Appended data for frequency 242 GHz
# Appended data for frequency 243 GHz
# Appended data for frequency 244 GHz
# Appended data for frequency 245 GHz
# Appended data for frequency 246 GHz
# Appended data for frequency 247 GHz
# Appended data for frequency 248 GHz
# Appended data for frequency 249 GHz
# Appended data for frequency 250 GHz
# Appended data for frequency 251 GHz
# Appended data for frequency 252 GHz
# Appended data for frequency 253 GHz
# Appended data for frequency 254 GHz
# Appended data for frequency 255 GHz
# Appended data for frequency 256 GHz
# Appended data for frequency 257 GHz
# Appended data for frequency 258 GHz
# Appended data for frequency 259 GHz
# Appended data for frequency 260 GHz
# Appended data for frequency 261 GHz
# Appended data for frequency 262 GHz
# Appended data for frequency 263 GHz
# Appended data for frequency 264 GHz
# Appended data for frequency 265 GHz
# Appended data for frequency 266 GHz
# Appended data for frequency 267 GHz
# Appended data for frequency 268 GHz
# Appended data for frequency 269 GHz
# Appended data for frequency 270 GHz
# Appended data for frequency 271 GHz
# Appended data for frequency 272 GHz
# Appended data for frequency 273 GHz
# Appended data for frequency 274 GHz
# Appended data for frequency 275 GHz
# Appended data for frequency 276 GHz
# Appended data for frequency 277 GHz
# Appended data for frequency 278 GHz
# Appended data for frequency 279 GHz
# Appended data for frequency 280 GHz
# Appended data for frequency 281 GHz
# Appended data for frequency 282 GHz
# Appended data for frequency 283 GHz
# Appended data for frequency 284 GHz
# Appended data for frequency 285 GHz
# Appended data for frequency 286 GHz
# Appended data for frequency 287 GHz
# Appended data for frequency 288 GHz
# Appended data for frequency 289 GHz
# Appended data for frequency 290 GHz
# Appended data for frequency 291 GHz
# Appended data for frequency 292 GHz
# Appended data for frequency 293 GHz
# Appended data for frequency 294 GHz
# Appended data for frequency 295 GHz
# Appended data for frequency 296 GHz
# Appended data for frequency 297 GHz
# Appended data for frequency 298 GHz
# Appended data for frequency 299 GHz
# Appended data for frequency 300 GHz
# Appended data for frequency 301 GHz
# Appended data for frequency 302 GHz
# Appended data for frequency 303 GHz
# Appended data for frequency 304 GHz
# Appended data for frequency 305 GHz
# Appended data for frequency 306 GHz
# Appended data for frequency 307 GHz
# Appended data for frequency 308 GHz
# Appended data for frequency 309 GHz
# Appended data for frequency 310 GHz
# Appended data for frequency 311 GHz
# Appended data for frequency 312 GHz
# Appended data for frequency 313 GHz
# Appended data for frequency 314 GHz
# Appended data for frequency 315 GHz
# Appended data for frequency 316 GHz
# Appended data for frequency 317 GHz
# Appended data for frequency 318 GHz
# Appended data for frequency 319 GHz
# Appended data for frequency 320 GHz
# Appended data for frequency 321 GHz
# Appended data for frequency 322 GHz
# Appended data for frequency 323 GHz
# Appended data for frequency 324 GHz
# Appended data for frequency 325 GHz
# Appended data for frequency 326 GHz
# Appended data for frequency 327 GHz
# Appended data for frequency 328 GHz
# Appended data for frequency 329 GHz
# Appended data for frequency 330 GHz
# Appended data for frequency 331 GHz
# Appended data for frequency 332 GHz
# Appended data for frequency 333 GHz
# Appended data for frequency 334 GHz
# Appended data for frequency 335 GHz
# Appended data for frequency 336 GHz
# Appended data for frequency 337 GHz
# Appended data for frequency 338 GHz
# Appended data for frequency 339 GHz
# Appended data for frequency 340 GHz
# Appended data for frequency 341 GHz
# Appended data for frequency 342 GHz
# Appended data for frequency 343 GHz
# Appended data for frequency 344 GHz
# Appended data for frequency 345 GHz
# Appended data for frequency 346 GHz
# Appended data for frequency 347 GHz
# Appended data for frequency 348 GHz
# Appended data for frequency 349 GHz
# Appended data for frequency 350 GHz
# Appended data for frequency 351 GHz
# Appended data for frequency 352 GHz
# Appended data for frequency 353 GHz
# Appended data for frequency 354 GHz
# Appended data for frequency 355 GHz
# Appended data for frequency 356 GHz
# Appended data for frequency 357 GHz
# Appended data for frequency 358 GHz
# Appended data for frequency 359 GHz
# Appended data for frequency 360 GHz
# Appended data for frequency 361 GHz
# Appended data for frequency 362 GHz
# Appended data for frequency 363 GHz
# Appended data for frequency 364 GHz
# Appended data for frequency 365 GHz
# Appended data for frequency 366 GHz
# Appended data for frequency 367 GHz
# Appended data for frequency 368 GHz
# Appended data for frequency 369 GHz
# Appended data for frequency 370 GHz
# Appended data for frequency 371 GHz
# Appended data for frequency 372 GHz
# Appended data for frequency 373 GHz
# Appended data for frequency 374 GHz
# Appended data for frequency 375 GHz
# Appended data for frequency 376 GHz
# Appended data for frequency 377 GHz
# Appended data for frequency 378 GHz
# Appended data for frequency 379 GHz
# Appended data for frequency 380 GHz
# Appended data for frequency 381 GHz
# Appended data for frequency 382 GHz
# Appended data for frequency 383 GHz
# Appended data for frequency 384 GHz
# Appended data for frequency 385 GHz
# Appended data for frequency 386 GHz
# Appended data for frequency 387 GHz
# Appended data for frequency 388 GHz
# Appended data for frequency 389 GHz
# Appended data for frequency 390 GHz
# Appended data for frequency 391 GHz
# Appended data for frequency 392 GHz
# Appended data for frequency 393 GHz
# Appended data for frequency 394 GHz
# Appended data for frequency 395 GHz
# Appended data for frequency 396 GHz
# Appended data for frequency 397 GHz
# Appended data for frequency 398 GHz
# Appended data for frequency 399 GHz
# Appended data for frequency 400 GHz
# Appended data for frequency 401 GHz
# Appended data for frequency 402 GHz
# Appended data for frequency 403 GHz
# Appended data for frequency 404 GHz
# Appended data for frequency 405 GHz
# Appended data for frequency 406 GHz
# Appended data for frequency 407 GHz
# Appended data for frequency 408 GHz
# Appended data for frequency 409 GHz
# Appended data for frequency 410 GHz
# Appended data for frequency 411 GHz
# Appended data for frequency 412 GHz
# Appended data for frequency 413 GHz
# Appended data for frequency 414 GHz
# Appended data for frequency 415 GHz
# Appended data for frequency 416 GHz
# Appended data for frequency 417 GHz
# Appended data for frequency 418 GHz
# Appended data for frequency 419 GHz
# Appended data for frequency 420 GHz
# Appended data for frequency 421 GHz
# Appended data for frequency 422 GHz
# Appended data for frequency 423 GHz
# Appended data for frequency 424 GHz
# Appended data for frequency 425 GHz
# Appended data for frequency 426 GHz
# Appended data for frequency 427 GHz
# Appended data for frequency 428 GHz
# Appended data for frequency 429 GHz
# Appended data for frequency 430 GHz
# Appended data for frequency 431 GHz
# Appended data for frequency 432 GHz
# Appended data for frequency 433 GHz
# Appended data for frequency 434 GHz
# Appended data for frequency 435 GHz
# Appended data for frequency 436 GHz
# Appended data for frequency 437 GHz
# Appended data for frequency 438 GHz
# Appended data for frequency 439 GHz
# Appended data for frequency 440 GHz
# Appended data for frequency 441 GHz
# Appended data for frequency 442 GHz
# Appended data for frequency 443 GHz
# Appended data for frequency 444 GHz
# Appended data for frequency 445 GHz
# Appended data for frequency 446 GHz
# Appended data for frequency 447 GHz
# Appended data for frequency 448 GHz
# Appended data for frequency 449 GHz
# Appended data for frequency 450 GHz
# Appended data for frequency 451 GHz
# Appended data for frequency 452 GHz
# Appended data for frequency 453 GHz
# Appended data for frequency 454 GHz
# Appended data for frequency 455 GHz
# Appended data for frequency 456 GHz
# Appended data for frequency 457 GHz
# Appended data for frequency 458 GHz
# Appended data for frequency 459 GHz
# Appended data for frequency 460 GHz
# Appended data for frequency 461 GHz
# Appended data for frequency 462 GHz
# Appended data for frequency 463 GHz
# Appended data for frequency 464 GHz
# Appended data for frequency 465 GHz
# Appended data for frequency 466 GHz
# Appended data for frequency 467 GHz
# Appended data for frequency 468 GHz
# Appended data for frequency 469 GHz
# Appended data for frequency 470 GHz
# Appended data for frequency 471 GHz
# Appended data for frequency 472 GHz
# Appended data for frequency 473 GHz
# Appended data for frequency 474 GHz
# Appended data for frequency 475 GHz
# Appended data for frequency 476 GHz
# Appended data for frequency 477 GHz
# Appended data for frequency 478 GHz
# Appended data for frequency 479 GHz
# Appended data for frequency 480 GHz
# Appended data for frequency 481 GHz
# Appended data for frequency 482 GHz
# Appended data for frequency 483 GHz
# Appended data for frequency 484 GHz
# Appended data for frequency 485 GHz
# Appended data for frequency 486 GHz
# Appended data for frequency 487 GHz
# Appended data for frequency 488 GHz
# Appended data for frequency 489 GHz
# Appended data for frequency 490 GHz
# Appended data for frequency 491 GHz
# Appended data for frequency 492 GHz
# Appended data for frequency 493 GHz
# Appended data for frequency 494 GHz
# Appended data for frequency 495 GHz
# Appended data for frequency 496 GHz
# Appended data for frequency 497 GHz
# Appended data for frequency 498 GHz
# Appended data for frequency 499 GHz
# Appended data for frequency 500 GHz
# Appended data for frequency 501 GHz
# Appended data for frequency 502 GHz
# Appended data for frequency 503 GHz
# Appended data for frequency 504 GHz
# Appended data for frequency 505 GHz
# Appended data for frequency 506 GHz
# Appended data for frequency 507 GHz
# Appended data for frequency 508 GHz
# Appended data for frequency 509 GHz
# Appended data for frequency 510 GHz
# Appended data for frequency 511 GHz
# Appended data for frequency 512 GHz
# Appended data for frequency 513 GHz
# Appended data for frequency 514 GHz
# Appended data for frequency 515 GHz
# Appended data for frequency 516 GHz
# Appended data for frequency 517 GHz
# Appended data for frequency 518 GHz
# Appended data for frequency 519 GHz
# Appended data for frequency 520 GHz
# Appended data for frequency 521 GHz
# Appended data for frequency 522 GHz
# Appended data for frequency 523 GHz
# Appended data for frequency 524 GHz
# Appended data for frequency 525 GHz
# Appended data for frequency 526 GHz
# Appended data for frequency 527 GHz
# Appended data for frequency 528 GHz
# Appended data for frequency 529 GHz
# Appended data for frequency 530 GHz
# Appended data for frequency 531 GHz
# Appended data for frequency 532 GHz
# Appended data for frequency 533 GHz
# Appended data for frequency 534 GHz
# Appended data for frequency 535 GHz
# Appended data for frequency 536 GHz
# Appended data for frequency 537 GHz
# Appended data for frequency 538 GHz
# Appended data for frequency 539 GHz
# Appended data for frequency 540 GHz
# Appended data for frequency 541 GHz
# Appended data for frequency 542 GHz
# Appended data for frequency 543 GHz
# Appended data for frequency 544 GHz
# Appended data for frequency 545 GHz
# Appended data for frequency 546 GHz
# Appended data for frequency 547 GHz
# Appended data for frequency 548 GHz
# Appended data for frequency 549 GHz
# Appended data for frequency 550 GHz
# Appended data for frequency 551 GHz
# Appended data for frequency 552 GHz
# Appended data for frequency 553 GHz
# Appended data for frequency 554 GHz
# Appended data for frequency 555 GHz
# Appended data for frequency 556 GHz
# Appended data for frequency 557 GHz
# Appended data for frequency 558 GHz
# Appended data for frequency 559 GHz
# Appended data for frequency 560 GHz
# Appended data for frequency 561 GHz
# Appended data for frequency 562 GHz
# Appended data for frequency 563 GHz
# Appended data for frequency 564 GHz
# Appended data for frequency 565 GHz
# Appended data for frequency 566 GHz
# Appended data for frequency 567 GHz
# Appended data for frequency 568 GHz
# Appended data for frequency 569 GHz
# Appended data for frequency 570 GHz
# Appended data for frequency 571 GHz
# Appended data for frequency 572 GHz
# Appended data for frequency 573 GHz
# Appended data for frequency 574 GHz
# Appended data for frequency 575 GHz
# Appended data for frequency 576 GHz
# Appended data for frequency 577 GHz
# Appended data for frequency 578 GHz
# Appended data for frequency 579 GHz
# Appended data for frequency 580 GHz
# Appended data for frequency 581 GHz
# Appended data for frequency 582 GHz
# Appended data for frequency 583 GHz
# Appended data for frequency 584 GHz
# Appended data for frequency 585 GHz
# Appended data for frequency 586 GHz
# Appended data for frequency 587 GHz
# Appended data for frequency 588 GHz
# Appended data for frequency 589 GHz
# Appended data for frequency 590 GHz
# Appended data for frequency 591 GHz
# Appended data for frequency 592 GHz
# Appended data for frequency 593 GHz
# Appended data for frequency 594 GHz
# Appended data for frequency 595 GHz
# Appended data for frequency 596 GHz
# Appended data for frequency 597 GHz
# Appended data for frequency 598 GHz
# Appended data for frequency 599 GHz
# Appended data for frequency 600 GHz
# DATA ACQUISITION COMPLETE

# %%
#save to csv
df.to_csv(csv_file, index = False)
log_and_print(f"The data has been saved to {csv_file}, previous file may have been overwritten.")
pd.read_csv(csv_file)
# Out:
# The data has been saved to ../Data/Internal_Reflection_Test/Tables/f_vs_vlockin_intref_24p314.csv, previous file may have been overwritten.
#      Desired Frequency (GHz)  Measured Frequency (GHz)  Vlockin (microvolts)
# 0                         70                 70.063561              1.765790
# 1                         71                 70.902042              2.190490
# 2                         72                 71.901961              1.013290
# 3                         73                 72.902718              0.521544
# 4                         74                 73.901206              1.296410
# ..                       ...                       ...                   ...
# 526                      596                595.901788              0.379981
# 527                      597                596.902985              0.484291
# 528                      598                597.902620              0.268223
# 529                      599                598.900060              0.327827
# 530                      600                599.904529              0.260772
#
# [531 rows x 3 columns]

# %%
#Plot f vs. entered Vlockin with a log scale
plt.figure(figsize = (10, 6))
plt.plot(df['Desired Frequency (GHz)'], df['Vlockin (microvolts)'])
plt.yscale('log')
plt.xlabel('Frequency (GHz)')
plt.ylabel('Vlockin (microvolts)')
plt.title('f vs. Vlockin')
#save to png
plt.savefig(plot_file)
log_and_print(f"The data has been saved to {plot_file}, previous file may have been overwritten.")
#display the plot
plt.show()
# Out:
# The data has been saved to ../Data/Internal_Reflection_Test/Plots/f_vs_vlockin_intref_24p314.png, previous file may have been overwritten.

# %%
#Either power down PROWLS and turn off bias amplitude, bias offset, and lasers, or keep them all on.
with Client(SerialConnection(dlc_connection_port)) as client:
    if power_down:
        client.set('lockin:mod-out-amplitude', 0)
        client.set('lockin:mod-out-offset', 0)
        #wait 5 secs for DLC smart to adjust
        time.sleep(5)
        client.set('laser-operation:emission-global-enable', False)
        log_and_print(f"PROWLS powered down")
    else:
        log_and_print(f"PROWLS did NOT power down")
    log_and_print(f"Current DLC Smart Bias Amplitude (V): {client.get('lockin:mod-out-amplitude')}")
    log_and_print(f"Current DLC Smart Bias Offset (V): {client.get('lockin:mod-out-offset')}")
    log_and_print(f'Lasers on: {client.get('laser-operation:emission-global-enable')}')
# Out:
# PROWLS powered down
# Current DLC Smart Bias Amplitude (V): 0
# Current DLC Smart Bias Offset (V): 0
# Lasers on: False
